# %% [markdown]
# # Practice Exercise – Model Training and Evaluation

# %% [markdown]
# # Problem 1: Spam email classification
#
# In this example, you will work on classifying emails as spam or not spam.
#
# You will use the [Spambase Data Set](https://archive.ics.uci.edu/ml/datasets/Spambase) from the University of California, Irvine (UCI) Machine Learning Repository.
#
# __Source information:__
#
# Creators:
# Mark Hopkins, Erik Reeber, George Forman, Jaap Suermondt, Hewlett-Packard Labs, 1501 Page Mill Rd., Palo Alto, CA 94304
#
# Donor:
# George Forman gforman@hpl.hp.com 650-857-7835
#
# ----------------------------------------------------------------------------
#
# The data has 57 attributes and 1 target. They are described below.
# - 48 continuous real [0,100] attributes of type word_freq_WORD
# = percentage of words in the e-mail that match WORD,
# i.e. 100 * (number of times the WORD appears in the e-mail) /
# total number of words in e-mail.  A "word" in this case is any
# string of alphanumeric characters bounded by non-alphanumeric
# characters or end-of-string.
#
# - 6 continuous real [0,100] attributes of type char_freq_CHAR
# = percentage of characters in the e-mail that match CHAR,
# i.e. 100 * (number of CHAR occurrences) / total characters in e-mail
#
# - 1 continuous real [1,...] attribute of type capital_run_length_average
# = average length of uninterrupted sequences of capital letters
#
# - 1 continuous integer [1,...] attribute of type capital_run_length_longest
# = length of longest uninterrupted sequence of capital letters
#
# - 1 continuous integer [1,...] attribute of type capital_run_length_total
# = sum of length of uninterrupted sequences of capital letters
# = total number of capital letters in the e-mail
#
# - 1 nominal {0,1} class attribute of type spam
# = denotes whether the e-mail was considered spam (1) or not (0), i.e. unsolicited commercial e-mail.

# %% [markdown]
# ## 1. Getting the data

# %%
import subprocess
import os

# Check whether the file is already in the desired path or if it needs to be downloaded
# File downloaded from source : https://archive.ics.uci.edu/ml/machine-learning-databases/spambase/spambase.data

base_path = '/home/ec2-user/SageMaker/data/'
file_path = 'spambase.data'

if not os.path.isfile(base_path + file_path):
    subprocess.run(['mkdir', '-p', base_path])
    subprocess.run(['aws', 's3', 'cp', 
                    's3://aws-tc-largeobjects/ILT-TF-200-MLDWTS/lab3/', 
                    base_path,'--recursive'])
else:
    print('File already downloaded!')

# %%
import csv
import numpy as np

data = []

f = open('/home/ec2-user/SageMaker/data/spambase.data')
reader = csv.reader(f)
next(reader, None)
for row in reader:
    data.append(row)
f.close()

# %% [markdown]
# Write the data into a DataFrame for easier visualization and analysis. Also, add the attribute names, which are from the "spambase.names" file in the dataset package.

# %%
import pandas as pd

df = pd.DataFrame(data=np.array(data).astype(np.float), columns=["word_freq_make",
            "word_freq_address",
            "word_freq_all",
            "word_freq_3d",
            "word_freq_our",
            "word_freq_over",
            "word_freq_remove",
            "word_freq_internet",
            "word_freq_order",
            "word_freq_mail",
            "word_freq_receive",
            "word_freq_will",
            "word_freq_people",
            "word_freq_report",
            "word_freq_addresses",
            "word_freq_free",
            "word_freq_business",
            "word_freq_email",
            "word_freq_you",
            "word_freq_credit",
            "word_freq_your",
            "word_freq_font",
            "word_freq_000",
            "word_freq_money",
            "word_freq_hp",
            "word_freq_hpl",
            "word_freq_george",
            "word_freq_650",
            "word_freq_lab",
            "word_freq_labs",
            "word_freq_telnet",
            "word_freq_857",
            "word_freq_data",
            "word_freq_415",
            "word_freq_85",
            "word_freq_technology",
            "word_freq_1999",
            "word_freq_parts",
            "word_freq_pm",
            "word_freq_direct",
            "word_freq_cs",
            "word_freq_meeting",
            "word_freq_original",
            "word_freq_project",
            "word_freq_re",
            "word_freq_edu",
            "word_freq_table",
            "word_freq_conference",
            "char_freq_;",
            "char_freq_(",
            "char_freq_[",
            "char_freq_!",
            "char_freq_$",
            "char_freq_#",
            "capital_run_length_average",
            "capital_run_length_longest",
            "capital_run_length_total",
            "target"]
            )

# %% [markdown]
# Look at the shape of the data. There are 58 columns (including the target) as expected.

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.21               0.28           0.50           0.0
# 1            0.06               0.00           0.71           0.0
# 2            0.00               0.00           0.00           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.14            0.28              0.21                0.07
# 1           1.23            0.19              0.19                0.12
# 2           0.63            0.00              0.31                0.63
# 3           0.63            0.00              0.31                0.63
# 4           1.85            0.00              0.00                1.85
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.94  ...         0.00        0.132
# 1             0.64            0.25  ...         0.01        0.143
# 2             0.31            0.63  ...         0.00        0.137
# 3             0.31            0.63  ...         0.00        0.135
# 4             0.00            0.00  ...         0.00        0.223
#
#    char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0          0.0        0.372        0.180        0.048
# 1          0.0        0.276        0.184        0.010
# 2          0.0        0.137        0.000        0.000
# 3          0.0        0.135        0.000        0.000
# 4          0.0        0.000        0.000        0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       5.114                       101.0
# 1                       9.821                       485.0
# 2                       3.537                        40.0
# 3                       3.537                        40.0
# 4                       3.000                        15.0
#
#    capital_run_length_total  target
# 0                    1028.0     1.0
# 1                    2259.0     1.0
# 2                     191.0     1.0
# 3                     191.0     1.0
# 4                      54.0     1.0
#
# [5 rows x 58 columns]

# %% [markdown]
# The `df.describe()` function presents a statistical summary of the features.

# %%
df.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4600.000000        4600.000000    4600.000000   4600.000000
# mean         0.104576           0.212922       0.280578      0.065439
# std          0.305387           1.290700       0.504170      1.395303
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4600.000000     4600.000000       4600.000000         4600.000000
# mean        0.312222        0.095922          0.114233            0.105317
# std         0.672586        0.273850          0.391480            0.401112
# min         0.000000        0.000000          0.000000            0.000000
# 25%         0.000000        0.000000          0.000000            0.000000
# 50%         0.000000        0.000000          0.000000            0.000000
# 75%         0.382500        0.000000          0.000000            0.000000
# max        10.000000        5.880000          7.270000           11.110000
#
#        word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# count      4600.000000     4600.000000  ...  4600.000000  4600.000000
# mean          0.090087        0.239465  ...     0.038583     0.139061
# std           0.278643        0.644816  ...     0.243497     0.270377
# min           0.000000        0.000000  ...     0.000000     0.000000
# 25%           0.000000        0.000000  ...     0.000000     0.000000
# 50%           0.000000        0.000000  ...     0.000000     0.065000
# 75%           0.000000        0.160000  ...     0.000000     0.188000
# max           5.260000       18.180000  ...     4.385000     9.752000
#
#        char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# count  4600.000000  4600.000000  4600.000000  4600.000000
# mean      0.016980     0.268960     0.075827     0.044248
# std       0.109406     0.815726     0.245906     0.429388
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.314250     0.052000     0.000000
# max       4.081000    32.478000     6.003000    19.829000
#
#        capital_run_length_average  capital_run_length_longest  \
# count                 4600.000000                 4600.000000
# mean                     5.191827                   52.170870
# std                     31.732891                  194.912453
# min                      1.000000                    1.000000
# 25%                      1.588000                    6.000000
# 50%                      2.275500                   15.000000
# 75%                      3.705250                   43.000000
# max                   1102.500000                 9989.000000
#
#        capital_run_length_total       target
# count               4600.000000  4600.000000
# mean                 283.290435     0.393913
# std                  606.413764     0.488669
# min                    1.000000     0.000000
# 25%                   35.000000     0.000000
# 50%                   95.000000     0.000000
# 75%                  265.250000     1.000000
# max                15841.000000     1.000000
#
# [8 rows x 58 columns]

# %% [markdown]
# ## 2. Training the model
#
# In this section, you will do the following:
#
# - Split the dataset into training, validation, and test subsets
# - Use the Amazon SageMaker linear learner algorithm to train the model

# %% [markdown]
# > ### Question 1 - Train-test-validation split
# >
# > An important part of training a machine learning model is splitting the data into training, validation, and test subsets. You will use the `train_test_split()` function from the `sklearn` library ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)).
#
# >Look at this example:
# >
# > `train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)`
# >
# > This function splits input feature `X` and target `y` pairs by a given ratio (test_size). This specific example splits the data into training (80%) and test (20%) subsets.
# >
# > Use this function __twice__ to split the data into __training (80%)__, __validation (10%)__, and __test (10%)__ subsets.

# %%
from sklearn.model_selection import train_test_split

# Get the feature values until the target column (not included)
X = df.values[:, :-1].astype(np.float32)

# Get the target column
y = df.values[:, -1].astype(np.float32)

# Get 80% of the data for training; the remaining 20% will be for validation and test
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)

# Split the remaining 20% of data as 10% test and 10% validation
test_features, val_features, test_labels, val_labels = train_test_split(test_features, test_labels, test_size=0.5)

print(f"Length of train_features is: {train_features.shape}")
print(f"Length of train_labels is: {train_labels.shape}")
print(f"Length of val_features is: {val_features.shape}")
print(f"Length of val_labels is: {val_labels.shape}")
print(f"Length of test_features is: {test_features.shape}")
print(f"Length of test_labels is: {test_labels.shape}")
# Out:
# Length of train_features is: (3680, 57)
# Length of train_labels is: (3680,)
# Length of val_features is: (460, 57)
# Length of val_labels is: (460,)
# Length of test_features is: (460, 57)
# Length of test_labels is: (460,)

# %% [markdown]
# Now, call the Amazon SageMaker `LinearLearner()` algorithm. This example uses an `ml.m4.xlarge` instance for training. `predictor_type` is set to __'binary_classifier'__ because there are two classes: "spam" and "not spam".

# %%
import sagemaker

# Call the LinearLearner estimator object
binary_estimator = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               train_instance_count=1,
                                               train_instance_type='ml.m4.xlarge',
                                               predictor_type='binary_classifier')

# %% [markdown]
# Use the `record_set()` function of the binary_estimator to set the training, validation, and test parts of the estimator.

# %%
train_records = binary_estimator.record_set(train_features, train_labels, channel='train')
val_records = binary_estimator.record_set(val_features, val_labels, channel='validation')
test_records = binary_estimator.record_set(test_features, test_labels, channel='test')

# %% [markdown]
# The `fit()` function applies a distributed version of the Stochastic Gradient Descent (SGD) algorithm, and we are sending the data to it.

# %%
binary_estimator.fit([train_records, val_records, test_records])
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-07-30 13:46:36 Starting - Starting the training job...
# 2020-07-30 13:46:38 Starting - Launching requested ML instances......
# 2020-07-30 13:47:48 Starting - Preparing the instances for training......
# 2020-07-30 13:48:51 Downloading - Downloading input data...
# 2020-07-30 13:49:36 Training - Downloading the training image...
# 2020-07-30 13:49:55 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [07/30/2020 13:49:59 INFO 140460580239168] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [07/30/2020 13:49:59 INFO 140460580239168] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'57', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier'}
# [07/30/2020 13:49:59 INFO 140460580239168] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'57', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'binary_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [07/30/2020 13:49:59 WARNING 140460580239168] Loggers have already been setup.
# Process 1 is a worker.
# [07/30/2020 13:50:00 INFO 140460580239168] Using default worker.
# [07/30/2020 13:50:00 INFO 140460580239168] Checkpoint loading and saving are disabled.
# [2020-07-30 13:50:00.214] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-07-30 13:50:00.217] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-07-30 13:50:00.238] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 27, "num_examples": 1, "num_bytes": 276000}
# [07/30/2020 13:50:00 INFO 140460580239168] Create Store: local
# [2020-07-30 13:50:00.271] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration":
"Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117000.987041}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6987566077190897, "sum": 0.6987566077190897, "min": 0.6987566077190897}}, "EndTime": 1596117000.987124, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117000.987104}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6997798753821332, "sum": 0.6997798753821332, "min": 0.6997798753821332}}, "EndTime": 1596117000.987189, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117000.987171}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.7346647843070652, "sum": 0.7346647843070652, "min": 0.7346647843070652}}, "EndTime": 1596117000.987254, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117000.987234}
#
# #metrics {"Metrics": {"validation_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6759960672129756, "sum": 0.6759960672129756, "min": 0.6759960672129756}}, "EndTime": 1596117000.987318, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117000.987298}
#
# [07/30/2020 13:50:00 INFO 140460580239168] #quality_metric: host=algo-1, epoch=0, validation binary_classification_cross_entropy_objective <loss>=0.62734375
# [07/30/2020 13:50:00 INFO 140460580239168] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=sampled_accuracy, value=0.917391304348
# [07/30/2020 13:50:00 INFO 140460580239168] Epoch 0: Loss improved. Updating best model
# [07/30/2020 13:50:00 INFO 140460580239168] Saving model for epoch: 0
# [07/30/2020 13:50:00 INFO 140460580239168] Saved checkpoint to "/tmp/tmplJxp9r/mx-mod-0000.params"
# [07/30/2020 13:50:00 INFO 140460580239168] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 3680, "sum": 3680.0, "min": 3680}, "Total Batches Seen": {"count": 1, "max": 9, "sum": 9.0, "min": 9}, "Total Records Seen": {"count": 1, "max": 8360, "sum": 8360.0, "min": 8360}, "Max Records Seen Between Resets": {"count": 1, "max": 3680, "sum": 3680.0, "min": 3680}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1596117000.996197, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117000.384853}
#
# [07/30/2020 13:50:00 INFO 140460580239168] #throughput_metric: host=algo-1, train throughput=6018.43180375 records/second
# [2020-07-30 13:50:01.102] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 106, "num_examples": 4, "num_bytes": 1015680}
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.59810498046875, "sum": 0.59810498046875, "min": 0.59810498046875}}, "EndTime": 1596117001.102934, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.10282}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6131736653645833, "sum": 0.6131736653645833, "min": 0.6131736653645833}}, "EndTime": 1596117001.103047, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103024}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6611929117838542, "sum": 0.6611929117838542, "min": 0.6611929117838542}}, "EndTime": 1596117001.103121, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103103}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6487259318033854, "sum": 0.6487259318033854, "min": 0.6487259318033854}}, "EndTime": 1596117001.103196, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103177}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3022576904296875, "sum": 0.3022576904296875, "min": 0.3022576904296875}}, "EndTime": 1596117001.103263, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103246}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3027496744791667, "sum": 0.3027496744791667, "min": 0.3027496744791667}}, "EndTime": 1596117001.103329, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103312}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3023041076660156, "sum": 0.3023041076660156, "min": 0.3023041076660156}}, "EndTime": 1596117001.103395, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103378}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3078898213704427, "sum": 0.3078898213704427, "min": 0.3078898213704427}}, "EndTime": 1596117001.10346, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103442}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6204397786458333, "sum": 0.6204397786458333, "min": 0.6204397786458333}}, "EndTime": 1596117001.103519, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103503}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6336550089518229, "sum": 0.6336550089518229, "min": 0.6336550089518229}}, "EndTime": 1596117001.103579, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103561}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6070606079101563, "sum": 0.6070606079101563, "min": 0.6070606079101563}}, "EndTime": 1596117001.103641, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103624}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6139663696289063, "sum": 0.6139663696289063, "min": 0.6139663696289063}}, "EndTime": 1596117001.103706, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103688}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3004559020996094, "sum": 0.3004559020996094, "min": 0.3004559020996094}}, "EndTime": 1596117001.103769, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103752}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.2972016805013021, "sum": 0.2972016805013021, "min": 0.2972016805013021}}, "EndTime": 1596117001.103832, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103814}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.30436566162109374, "sum": 0.30436566162109374, "min": 0.30436566162109374}}, "EndTime": 1596117001.103896, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.103877}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.3035921325683594, "sum": 0.3035921325683594, "min": 0.3035921325683594}}, "EndTime": 1596117001.103969, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.10395}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.5877744344075521, "sum": 0.5877744344075521, "min": 0.5877744344075521}}, "EndTime": 1596117001.104034, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.104016}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6191441243489584, "sum": 0.6191441243489584, "min": 0.6191441243489584}}, "EndTime": 1596117001.1041, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001.104081}
#
# #metrics {"Metrics": {"train_binary_classification_cross_entropy_objective": {"count": 1, "max": 0.6407766316731771, "sum": 0.6407766316731771, "min": 0.6407766316731771}}, "EndTime": 1596117001.104168, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596117001
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, validation binary_classification_cross_entropy_objective <loss>=0.191075134277
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, validation binary_classification_accuracy <score>=0.928260869565
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, validation binary_f_1.000 <score>=0.914285714286
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, validation precision <score>=0.926315789474
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, validation recall <score>=0.902564102564
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, validation roc_auc_score <score>=0.978848572811
# [07/30/2020 13:50:08 INFO 140460580239168] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [07/30/2020 13:50:08 INFO 140460580239168] Saved checkpoint to "/tmp/tmpMfhrJ5/mx-mod-0000.params"
# [2020-07-30 13:50:08.492] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 8275, "num_examples": 1, "num_bytes": 126960}
# [2020-07-30 13:50:08.497] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 4, "num_examples": 1, "num_bytes": 126960}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 460, "sum": 460.0, "min": 460}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 460, "sum": 460.0, "min": 460}, "Max Records Seen Between Resets": {"count": 1, "max": 460, "sum": 460.0, "min": 460}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1596117008.498976, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1596117008.492499}
#
# [07/30/2020 13:50:08 INFO 140460580239168] #test_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.19721119092858355)
# [07/30/2020 13:50:08 INFO 140460580239168] #test_score (algo-1) : ('binary_classification_accuracy', 0.9304347826086956)
# [07/30/2020 13:50:08 INFO 140460580239168] #test_score (algo-1) : ('binary_f_1.000', 0.9116022099447514)
# [07/30/2020 13:50:08 INFO 140460580239168] #test_score (algo-1) : ('precision', 0.873015873015873)
# [07/30/2020 13:50:08 INFO 140460580239168] #test_score (algo-1) : ('recall', 0.953757225433526)
# [07/30/2020 13:50:08 INFO 140460580239168] #test_score (algo-1) : ('roc_auc_score', 0.9761736923727619)
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, test binary_classification_cross_entropy_objective <loss>=0.197211190929
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.930434782609
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.911602209945
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, test precision <score>=0.873015873016
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, test recall <score>=0.953757225434
# [07/30/2020 13:50:08 INFO 140460580239168] #quality_metric: host=algo-1, test roc_auc_score <score>=0.976173692373
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 8533.637046813965, "sum": 8533.637046813965, "min": 8533.637046813965}, "finalize.time": {"count": 1, "max": 359.3618869781494, "sum": 359.3618869781494, "min": 359.3618869781494}, "initialize.time": {"count": 1, "max": 164.40391540527344, "sum": 164.40391540527344, "min": 164.40391540527344}, "check_early_stopping.time": {"count": 16, "max": 1.4848709106445312, "sum": 17.479896545410156, "min": 0.8900165557861328}, "setuptime": {"count": 1, "max": 28.53703498840332, "sum": 28.53703498840332, "min": 28.53703498840332}, "update.time": {"count": 15, "max": 657.3898792266846, "sum": 7695.822238922119, "min": 458.2021236419678}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1596117008.505196, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1596117000.209602}
#
#
# 2020-07-30 13:50:18 Uploading - Uploading generated training model
# 2020-07-30 13:50:18 Completed - Training job completed
# Training seconds: 87
# Billable seconds: 87

# %% [markdown]
# ## 3. Evaluating the model
#
# In this section, you will look at how the model performs with the test dataset.

# %% [markdown]
# ### Amazon SageMaker analytics
# You can use `sagemaker.analytics` to get some performance metrics. This doesn't require deploying the model. Because this is a classification problem, you can check accuracy, precision, and recall.

# %%
sagemaker.analytics.TrainingJobAnalytics(binary_estimator._current_job_name, 
                                         metric_names = ['test:binary_classification_accuracy', 
                                                         'test:precision', 
                                                         'test:recall']
                                        ).dataframe()
# Out:
#    timestamp                          metric_name     value
# 0        0.0  test:binary_classification_accuracy  0.930435
# 1        0.0                       test:precision  0.873016
# 2        0.0                          test:recall  0.953757

# %% [markdown]
# ### Deploying the model
# To deploy the model, run the following cell.
#
# **Note:** This takes some time to complete. While you are waiting, think about the answer to question 2.

# %%
binary_predictor = binary_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ---------------!

# %% [markdown]
# > ### Question 2 - Evaluation metric selection
# > You need to consider the business and its related restrictions when selecting the evaluation metric. In this case, spam detection requires being careful about false positives. A false positive means a good email is classified as a spam email. Because spam emails usually go to a spam folder, a user could lose important information from a false positive.
#
# >Some well-known evaluation metrics include the following:
# - Accuracy = ( TP + TN ) / ( TP + FP + FN + TN )
# - Precision = ( TP ) / ( TP + FP )
# - Recall = ( TP ) / ( TP + FN )
# >
# >In light of the provided information, which of the provided metrics do you think is the best to consider?

# %% [markdown]
# **Answer:** Precision is the choice of metric here as it accounts for the false positives. High precision means high TP and low FP.

# %% [markdown]
# Now that you have a hosted endpoint running, you can make real-time predictions from the model easily, simply by making an http POST request. First, you need to set up serializers and deserializers for passing the `test_features` NumPy arrays to the model behind the endpoint. You will also calculate the confusion matrix for the model to evaluate how it has done on the test data.

# %% [markdown]
# > ### Question 3 - Calculate metrics
# >
# > In this question, you are asked to calculate some important evaluation metrics. The accuracy calculation is used as an example. Calculate the precision and recall after accuracy.
# >
# >**Hint:** You can check your calculated values with the `sagemaker.analytics` results you got in the beginning of this section.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get predictions for each batch with size of 25
def predict_batches(predictor, features, labels):
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(features, 25)]
    # Parse protobuf responses to extract predicted labels
    extract_label = lambda x: x.label['predicted_label'].float32_tensor.values
    preds = np.concatenate([np.array([extract_label(x) for x in batch]) for batch in prediction_batches])
    preds = preds.reshape((-1,))

    # Calculate accuracy, precision, and recall
    accuracy = (preds == labels).sum() / len(labels)
    print(f'Accuracy: {accuracy}')
    
    # Calculate precision
    precision = (preds[preds == 1] == labels[preds == 1]).sum() / len(preds[preds == 1])
    print(f'Precision: {precision}')
    
    # Calculate recall
    recall = (preds[preds == 1] == labels[preds == 1]).sum() / len(labels[labels == 1])
    print(f'Recall: {recall}')
    
    confusion_matrix = pd.crosstab(index=labels, columns=np.round(preds), rownames=['True'], colnames=['predictions']).astype(int)
    plt.figure(figsize = (5,5))
    sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap="YlGnBu").set_title('Confusion Matrix')

# %% [markdown]
# Get training performance

# %%
predict_batches(binary_predictor, train_features, train_labels)
# Out:
# Accuracy: 0.9225543478260869
# Precision: 0.8835208471211119
# Recall: 0.9245152354570637

# %% [markdown]
# Get test performance

# %%
predict_batches(binary_predictor, test_features, test_labels)
# Out:
# Accuracy: 0.9304347826086956
# Precision: 0.873015873015873
# Recall: 0.953757225433526

# %% [markdown]
# > ### Question 4 - Compare training-test results
# > Do you see a big difference between training and test performance?

# %% [markdown]
# **Answer**: The two performances look very similar. We didn't experience overfitting here.

# %% [markdown]
# ## 4. Conclusion
# In this exercise, you developed a binary classifier using the linear learning algorithm in Amazon SageMaker. You also reviewed important concepts such as training, validation, and test splits; confusion matrices; and classification metrics. Overall, the model resulted in over 90% in the accuracy, precision, and recall metrics.

# %% [markdown]
# ----------------------------------------------------------------------------
# # Problem 2: Diabetes progression prediction (regression)
#
# For regression, you will work with a health-related dataset to predict diabetes.
#
# You will use the [Diabetes Data](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html).
#
# The __Scikit-learn__ library hosts this data as well. You will use this library to load the dataset.
#
# Fields in this dataset:
#
# Input:
# 1 - age
# 2 - sex
# 3 - bmi (Body mass index)
# 4 - bp (Blood pressure)
# 5 - s1 (Serum measurement 1)
# 6 - s2 (Serum measurement 2)
# 7 - s3 (Serum measurement 3)
# 8 - s4 (Serum measurement 4)
# 9 - s5 (Serum measurement 5)
# 10 - s6 (Serum measurement 6)
#
# Output:
# 11 - y (A quantitative measure of disease progression one year after baseline)

# %% [markdown]
# ## 1. Getting the data

# %%
import numpy as np
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()
X, y = diabetes.data.astype(np.float32), diabetes.target.astype(np.float32)

print("X shape:", X.shape)
print("Y shape:", y.shape)
# Out:
# X shape: (442, 10)
# Y shape: (442,)

# %%
import pandas as pd

df = pd.DataFrame(data=np.column_stack((X, y)), 
                  columns=['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6', 'y']
                 )

# %% [markdown]
# **Note:** The features are normalized and scaled beforehand.

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6      y
# 0 -0.002592  0.019908 -0.017646  151.0
# 1 -0.039493 -0.068330 -0.092204   75.0
# 2 -0.002592  0.002864 -0.025930  141.0
# 3  0.034309  0.022692 -0.009362  206.0
# 4 -0.002592 -0.031991 -0.046641  135.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for col in ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']:
    plt.hist(df[col].values)
    plt.title(col + ' distribution')
    plt.xlabel(col)
    plt.ylabel('Counts')
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(y)
plt.title('Target values')
plt.xlabel('y')
plt.ylabel('Counts')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Training the model
#
# In this section, you will do the following:
#
# - Split the dataset into training, validation, and test subsets
# - Use the Amazon SageMaker linear learner algorithm to train the model

# %% [markdown]
# > ### Question 1 - Train-test-validation split
# >
# > An important part of training a machine learning model is splitting the data into training, validation, and test subsets. You will use the `train_test_split()` function from the `sklearn` library [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html).
#
# >Look at this example:
# >
# > `train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)`
# >
# > This function splits input feature `X` and target `y` pairs by a given ratio (test_size). This specific example splits the data into training (80%) and test (20%) subsets.
# >
# > Use this function __twice__ to split the data into __training (80%)__, __validation (10%)__, and __test (10%)__ subsets.

# %%
from sklearn.model_selection import train_test_split

# Get 80% of the data for training; the remaining 20% will be for validation and test
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)

# Split the remaining 20% of data as 10% test and 10% validation
test_features, val_features, test_labels, val_labels = train_test_split(test_features, test_labels, test_size=0.5)

print(f"Length of train_features is: {train_features.shape}")
print(f"Length of train_labels is: {train_labels.shape}")
print(f"Length of val_features is: {val_features.shape}")
print(f"Length of val_labels is: {val_labels.shape}")
print(f"Length of test_features is: {test_features.shape}")
print(f"Length of test_labels is: {test_labels.shape}")
# Out:
# Length of train_features is: (353, 10)
# Length of train_labels is: (353,)
# Length of val_features is: (45, 10)
# Length of val_labels is: (45,)
# Length of test_features is: (44, 10)
# Length of test_labels is: (44,)

# %% [markdown]
# Now, call the Amazon SageMaker `LinearLearner()` algorithm. This example uses an `ml.m4.xlarge` instance for training. `predictor_type` is set to __'regressor'__ because this is a regression problem.

# %%
import sagemaker

# Call the LinearLearner estimator object
regression_model = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               train_instance_count=1,
                                               train_instance_type='ml.m4.xlarge',
                                               predictor_type='regressor')

# %% [markdown]
# Use the `record_set()` function of the binary_estimator to set the training, validation, and test parts of the estimator.

# %%
train_records = regression_model.record_set(train_features, train_labels, channel='train')
val_records = regression_model.record_set(val_features, val_labels, channel='validation')
test_records = regression_model.record_set(test_features, test_labels, channel='test')

# %% [markdown]
# The `fit()` function applies regression on this data.

# %%
regression_model.fit([train_records, val_records, test_records])
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 2020-07-30 13:58:30 Starting - Starting the training job...
# 2020-07-30 13:58:32 Starting - Launching requested ML instances......
# 2020-07-30 13:59:38 Starting - Preparing the instances for training......
# 2020-07-30 14:00:50 Downloading - Downloading input data...
# 2020-07-30 14:01:25 Training - Downloading the training image...
# 2020-07-30 14:01:58 Uploading - Uploading generated training model
# 2020-07-30 14:01:58 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [07/30/2020 14:01:49 INFO 140307087427392] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [07/30/2020 14:01:49 INFO 140307087427392] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'10', u'mini_batch_size': u'353', u'predictor_type': u'regressor'}
# [07/30/2020 14:01:49 INFO 140307087427392] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'10', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'353', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [07/30/2020 14:01:49 WARNING 140307087427392] Loggers have already been setup.
# Process 1 is a worker.
# [07/30/2020 14:01:49 INFO 140307087427392] Using default worker.
# [07/30/2020 14:01:49 INFO 140307087427392] Checkpoint loading and saving are disabled.
# [2020-07-30 14:01:49.490] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-07-30 14:01:49.491] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-07-30 14:01:49.516] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 27, "num_examples": 1, "num_bytes": 29652}
# [07/30/2020 14:01:49 INFO 140307087427392] Create Store: local
# [2020-07-30 14:01:49.559] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 41, "num_examples": 1, "num_bytes": 29652}
# [07/30/2020 14:01:49 INFO 140307087427392] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f9b6af46b50>
# [07/30/2020 14:01:49 INFO 140307087427392] Scaling model computed with parameters:
#  {'stdev_weight':
# [0.04726962 0.04749977 0.04814235 0.0472152  0.04659422 0.04752205
#  0.04931603 0.04896028 0.04709206 0.04909084]
# <NDArray 10 @cpu(0)>, 'stdev_label':
# [76.824844]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [151.60623]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [ 0.00154471 -0.00089624  0.00034946 -0.00222774 -0.00022419 -0.00016862
#   0.00089353 -0.00019108 -0.00079455 -0.00031499]
# <NDArray 10 @cpu(0)>}
# [07/30/2020 14:01:49 INFO 140307087427392] nvidia-smi took: 0.0251929759979 secs to identify 0 gpus
# [07/30/2020 14:01:49 INFO 140307087427392] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 2, "sum": 2.0, "min": 2}, "Total Records Seen": {"count": 1, "max": 706, "sum": 706.0, "min": 706}, "Max Records Seen Between Resets": {"count": 1, "max": 353, "sum": 353.0, "min": 353}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1596117709.670966, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1596117709.670897}
#
# [2020-07-30 14:01:49.710] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 39, "num_examples": 1, "num_bytes": 29652}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.878803458497477, "sum": 0.878803458497477, "min": 0.878803458497477}}, "EndTime": 1596117709.710971, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.710864}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0202983391521334, "sum": 1.0202983391521334, "min": 1.0202983391521334}}, "EndTime": 1596117709.711073, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711054}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8202702249413509, "sum": 0.8202702249413509, "min": 0.8202702249413509}}, "EndTime": 1596117709.711131, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711114}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1853140595952107, "sum": 1.1853140595952107, "min": 1.1853140595952107}}, "EndTime": 1596117709.711204, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711185}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.04227056314182, "sum": 1.04227056314182, "min": 1.04227056314182}}, "EndTime": 1596117709.711271, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711253}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1062273668499911, "sum": 1.1062273668499911, "min": 1.1062273668499911}}, "EndTime": 1596117709.711335, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711317}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0854845776436348, "sum": 1.0854845776436348, "min": 1.0854845776436348}}, "EndTime": 1596117709.711402, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711385}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0197426252932453, "sum": 1.0197426252932453, "min": 1.0197426252932453}}, "EndTime": 1596117709.711467, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711449}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1242478670547096, "sum": 1.1242478670547096, "min": 1.1242478670547096}}, "EndTime": 1596117709.711528, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711512}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0263073626726276, "sum": 1.0263073626726276, "min": 1.0263073626726276}}, "EndTime": 1596117709.71159, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711573}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1556592730557278, "sum": 1.1556592730557278, "min": 1.1556592730557278}}, "EndTime": 1596117709.711655, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711636}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0807710382823565, "sum": 1.0807710382823565, "min": 1.0807710382823565}}, "EndTime": 1596117709.71172, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711702}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0685096286849327, "sum": 1.0685096286849327, "min": 1.0685096286849327}}, "EndTime": 1596117709.711785, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711767}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9539882238458304, "sum": 0.9539882238458304, "min": 0.9539882238458304}}, "EndTime": 1596117709.711847, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.71183}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0894991520781692, "sum": 1.0894991520781692, "min": 1.0894991520781692}}, "EndTime": 1596117709.711909, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711893}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1348631429266998, "sum": 1.1348631429266998, "min": 1.1348631429266998}}, "EndTime": 1596117709.711972, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.711954}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0062067393878364, "sum": 1.0062067393878364, "min": 1.0062067393878364}}, "EndTime": 1596117709.712033, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596117709.

#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5966.354166666667, "sum": 5966.354166666667, "min": 5966.354166666667}}, "EndTime": 1596117710.268667, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1596117710.268651}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 6050.159027777778, "sum": 6050.159027777778, "min": 6050.159027777778}}, "EndTime": 1596117710.268735, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1596117710.268718}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5740.034722222223, "sum": 5740.034722222223, "min": 5740.034722222223}}, "EndTime": 1596117710.268795, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1596117710.268779}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 5451.196180555556, "sum": 5451.196180555556, "min": 5451.196180555556}}, "EndTime": 1596117710.268859, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1596117710.268842}
#
# [07/30/2020 14:01:50 INFO 140307087427392] #quality_metric: host=algo-1, epoch=6, validation mse_objective <loss>=4091.209375
# [07/30/2020 14:01:50 INFO 140307087427392] #early_stopping_criteria_metric: host=algo-1, epoch=6, criteria=mse_objective, value=3489.64027778
# [07/30/2020 14:01:50 INFO 140307087427392] Saving model for epoch: 6
# [07/30/2020 14:01:50 INFO 140307087427392] Saved checkpoint to "/tmp/tmp2tDbZG/mx-mod-0000.params"
# [07/30/2020 14:01:50 INFO 140307087427392] Early stop condition met. Stopping training.
# [07/30/2020 14:01:50 INFO 140307087427392] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 353, "sum": 353.0, "min": 353}, "Total Batches Seen": {"count": 1, "max": 9, "sum": 9.0, "min": 9}, "Total Records Seen": {"count": 1, "max": 3177, "sum": 3177.0, "min": 3177}, "Max Records Seen Between Resets": {"count": 1, "max": 353, "sum": 353.0, "min": 353}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1596117710.274042, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 6}, "StartTime": 1596117710.198692}
#
# [07/30/2020 14:01:50 INFO 140307087427392] #throughput_metric: host=algo-1, train throughput=4676.42633296 records/second
# [07/30/2020 14:01:50 WARNING 140307087427392] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [07/30/2020 14:01:50 WARNING 140307087427392] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2020-07-30 14:01:50.307] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 23, "duration": 9, "num_examples": 1, "num_bytes": 3780}
# [07/30/2020 14:01:50 INFO 140307087427392] #early_stopping_criteria_metric: host=algo-1, epoch=6, criteria=mse_objective, value=3489.64027778
# [2020-07-30 14:01:50.317] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 25, "duration": 1, "num_examples": 1, "num_bytes": 3780}
# [07/30/2020 14:01:50 INFO 140307087427392] #validation_score (algo-1) : ('mse_objective', 2929.9864583333333)
# [07/30/2020 14:01:50 INFO 140307087427392] #validation_score (algo-1) : ('mse', 2929.9864583333333)
# [07/30/2020 14:01:50 INFO 140307087427392] #validation_score (algo-1) : ('absolute_loss', 42.735416666666666)
# [07/30/2020 14:01:50 INFO 140307087427392] #quality_metric: host=algo-1, validation mse_objective <loss>=2929.98645833
# [07/30/2020 14:01:50 INFO 140307087427392] #quality_metric: host=algo-1, validation mse <loss>=2929.98645833
# [07/30/2020 14:01:50 INFO 140307087427392] #quality_metric: host=algo-1, validation absolute_loss <loss>=42.7354166667
# [07/30/2020 14:01:50 INFO 140307087427392] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 1, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 0.0001}
# [07/30/2020 14:01:50 INFO 140307087427392] Saved checkpoint to "/tmp/tmpOn9uul/mx-mod-0000.params"
# [2020-07-30 14:01:50.320] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 829, "num_examples": 1, "num_bytes": 3696}
# [2020-07-30 14:01:50.322] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 1, "num_examples": 1, "num_bytes": 3696}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 44, "sum": 44.0, "min": 44}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 44, "sum": 44.0, "min": 44}, "Max Records Seen Between Resets": {"count": 1, "max": 44, "sum": 44.0, "min": 44}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1596117710.322269, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1596117710.320548}
#
# [07/30/2020 14:01:50 INFO 140307087427392] #test_score (algo-1) : ('mse_objective', 3265.4133522727275)
# [07/30/2020 14:01:50 INFO 140307087427392] #test_score (algo-1) : ('mse', 3265.4133522727275)
# [07/30/2020 14:01:50 INFO 140307087427392] #test_score (algo-1) : ('absolute_loss', 49.35221169211648)
# [07/30/2020 14:01:50 INFO 140307087427392] #quality_metric: host=algo-1, test mse_objective <loss>=3265.41335227
# [07/30/2020 14:01:50 INFO 140307087427392] #quality_metric: host=algo-1, test mse <loss>=3265.41335227
# [07/30/2020 14:01:50 INFO 140307087427392] #quality_metric: host=algo-1, test absolute_loss <loss>=49.3522116921
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 1059.6880912780762, "sum": 1059.6880912780762, "min": 1059.6880912780762}, "finalize.time": {"count": 1, "max": 43.916940689086914, "sum": 43.916940689086914, "min": 43.916940689086914}, "initialize.time": {"count": 1, "max": 179.1849136352539, "sum": 179.1849136352539, "min": 179.1849136352539}, "check_early_stopping.time": {"count": 8, "max": 0.9310245513916016, "sum": 3.1282901763916016, "min": 0.21004676818847656}, "setuptime": {"count": 1, "max": 27.842998504638672, "sum": 27.842998504638672, "min": 27.842998504638672}, "update.time": {"count": 7, "max": 106.73713684082031, "sum": 577.5327682495117, "min": 70.30582427978516}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1596117710.325939, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1596117709.488222}
#
# Training seconds: 68
# Billable seconds: 68

# %% [markdown]
# ## 3. Evaluating the model
#
# In this section, you will look at how your model performs with the test dataset.

# %% [markdown]
# ### Amazon SageMaker analytics
# You can use `sagemaker.analytics` to get some performance metrics. This doesn't require deploying the model. Because this is a regression problem, you can check the **mean squared error**.

# %%
sagemaker.analytics.TrainingJobAnalytics(regression_model._current_job_name, 
                                         metric_names = ['test:mse']
                                        ).dataframe()
# Out:
#    timestamp metric_name        value
# 0        0.0    test:mse  3265.413352

# %% [markdown]
# ### Deploying the model
# To deploy the model, run the following cell.
#
# **Note:** This takes some time to complete. While you are waiting, think about the answer to question 2.

# %%
regression_predictor = regression_model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ---------------!

# %% [markdown]
# >### Question 2 - Calculate mean squared error
# >
# >In this question, you will calculate the mean squared error. It is given by this equation:
# >
# >mean squared error = $\displaystyle\frac{1}{n}\sum_{t=1}^{n}(pred_t-target_t)^2$
# >
# >Calculate the mean squared error using the __preds__ and __labels__ variables and print it.

# %%
import matplotlib.pyplot as plt

# Get predictions for each batch with size of 25
def predict_regression_batches(predictor, features, labels):
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(features, 25)]
    
    # Parse protobuf responses to extract predicted labels
    extract_score = lambda x: x.label['score'].float32_tensor.values
    preds = np.concatenate([np.array([extract_score(x) for x in batch]) for batch in prediction_batches])
    preds = preds.reshape((-1,))
    
    # Calculate mean squared error
    mse = sum((preds - labels)**2) / len(preds)
    print(mse)
    
    return preds

# %% [markdown]
# Now, get the results on the training and test subsets.

# %%
train_predictions = predict_regression_batches(regression_predictor, train_features, train_labels)
# Out:
# 3161.286364842092

# %%
test_predictions = predict_regression_batches(regression_predictor, test_features, test_labels)
# Out:
# 3265.4132901301464

# %% [markdown]
# ### Plotting results
#
# Let's look at some plots. Even though you calculated the mean squared error, it is still a good idea to examine the results visually.

# %% [markdown]
# ### Scatter plot
#
# With the scatter plot, you look at the fitted (predicted) values vs. true values. From the following plot, you can see that the predicted and true values followed a similar pattern overall.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(train_predictions, train_labels, c='b', s=40, alpha=0.25, label='Training')
plt.scatter(test_predictions, test_labels, c='g', s=40, label='Test')
plt.title("Scatter plot of Fitted vs True values")
plt.ylabel("True values")
plt.xlabel("Fitted values")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Residual plot
#
# Every data point has a residual. It is the difference between the real value and the predicted value. Residuals are calculated like this:
# $e = y - \hat y$
#
# A positive residual means a higher prediction than true value, and a negative residual means a lower prediction than true value.
#
# Take a look at the residual plot from running the following block. There is a random pattern in residuals, which is good. Other patterns you might see are the U-shape or inverted U-shape patterns. These two patterns point out some non-linearity in the data, which needs to be fixed. In this case case, we don't have that problem.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(train_predictions, train_predictions-train_labels, c='b', s=40, alpha=0.25, label='Training')
plt.scatter(test_predictions, test_predictions-test_labels, c='g', s=40, label='Test')
plt.hlines(y=0, xmin=0, xmax=300)
plt.title("Residual plots")
plt.ylabel("Residuals")
plt.xlabel("Fitted Values")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# >### Question 3: Residual plot assessment
# >
# >In general, looking at a residual plot allows you to realize a pattern. Patterns include:
# >- Random: This means the data is linear.
# >- U or inverse U shape: This points out some non-linearity in the data.
# >
# >What can you conclude from the residual plot?

# %% [markdown]
# **Answer**: The plot shows random residuals, meaning the data is linear.

# %% [markdown]
# ## 4. Conclusion
# In this exercise, you developed a regression model using the linear learning algorithm in Amazon SageMaker. You also covered important concepts, such as training, validation, and test splits; the mean squared error regression metric; and analysis of residual error.
